# %%
from rustworkx.visualization import mpl_draw as draw_graph
draw_graph(G, node_size=600, with_labels=True)

# %%
from ecoli.shared.utils.compositions import test_get_port_paths
from ecoli.shared.graph import construct_state_graph

paths = test_get_port_paths()
import rustworkx as rx
from rustworkx.visualization import mpl_draw as draw_graph
import numpy as np

n = len(paths)

G = rx.PyGraph()
graph.add_nodes_from(np.arange(0, n, 1))
# Out:
# { 'RNA_counts_listener.RNAs',
#   'RNA_counts_listener.global_time',
#   'RNA_counts_listener.listeners',
#   'RNA_counts_listener.timestep',
#   'allocator_1.allocate',
#   'allocator_1.bulk',
#   'allocator_1.request',
#   'allocator_2.allocate',
#   'allocator_2.bulk',
#   'allocator_2.request',
#   'allocator_3.allocate',
#   'allocator_3.bulk',
#   'allocator_3.request',
#   'bulk-timeline.bulk',
#   'bulk-timeline.global',
#   'bulk-timeline.media_id',
#   'division.agents',
#   'division.division_threshold',
#   'division.division_variable',
#   'division.full_chromosome',
#   'division.media_id',
#   'dna_supercoiling_listener.chromosomal_segments',
#   'dna_supercoiling_listener.global_time',
#   'dna_supercoiling_listener.listeners',
#   'dna_supercoiling_listener.timestep',
#   'ecoli-chromosome-replication_evolver.active_replisomes',
#   'ecoli-chromosome-replication_evolver.allocate',
#   'ecoli-chromosome-replication_evolver.bulk',
#   'ecoli-chromosome-replication_evolver.chromosome_domains',
#   'ecoli-chromosome-replication_evolver.environment',
#   'ecoli-chromosome-replication_evolver.full_chromosomes',
#   'ecoli-chromosome-replication_evolver.global_time',
#   'ecoli-chromosome-replication_evolver.listeners',
#   'ecoli-chromosome-replication_evolver.next_update_time',
#   'ecoli-chromosome-replication_evolver.oriCs',
#   'ecoli-chromosome-replication_evolver.process',
#   'ecoli-chromosome-replication_evolver.timestep',
#   'ecoli-chromosome-replication_requester.active_replisomes',
#   'ecoli-chromosome-replication_requester.bulk',
#   'ecoli-chromosome-replication_requester.chromosome_domains',
#   'ecoli-chromosome-replication_requester.environment',
#   'ecoli-chromosome-replication_requester.full_chromosomes',
#   'ecoli-chromosome-replication_requester.global_time',
#   'ecoli-chromosome-replication_requester.listeners',
#   'ecoli-chromosome-replication_requester.next_update_time',
#   'ecoli-chromosome-replication_requester.oriCs',
#   'ecoli-chromosome-replication_requester.process',
#   'ecoli-chromosome-replication_requester.request',
#   'ecoli-chromosome-replication_requester.timestep',
#   'ecoli-chromosome-structure.DnaA_boxes',
#   'ecoli-chromosome-structure.RNAs',
#   'ecoli-chromosome-structure.active_RNAPs',
#   'ecoli-chromosome-structure.active_replisomes',
#   'ecoli-chromosome-structure.active_ribosome',
#   'ecoli-chromosome-structure.bulk',
#   'ecoli-chromosome-structure.chromosomal_segments',
#   'ecoli-chromosome-structure.chromosome_domains',
#   'ecoli-chromosome-structure.full_chromosomes',
#   'ecoli-chromosome-structure.genes',
#   'ecoli-chromosome-structure.global_time',
#   'ecoli-chromosome-structure.listeners',
#   'ecoli-chromosome-structure.next_update_time',
#   'ecoli-chromosome-structure.oriCs',
#   'ecoli-chromosome-structure.promoters',
#   'ecoli-chromosome-structure.timestep',
#   'ecoli-complexation_evolver.allocate',
#   'ecoli-complexation_evolver.bulk',
#   'ecoli-complexation_evolver.global_time',
#   'ecoli-complexation_evolver.listeners',
#   'ecoli-complexation_evolver.next_update_time',
#   'ecoli-complexation_evolver.process',
#   'ecoli-complexation_evolver.timestep',
#   'ecoli-complexation_requester.bulk',
#   'ecoli-complexation_requester.global_time',
#   'ecoli-complexation_requester.listeners',
#   'ecoli-complexation_requester.next_update_time',
#   'ecoli-complexation_requester.process',
#   'ecoli-complexation_requester.request',
#   'ecoli-complexation_requester.timestep',
#   'ecoli-equilibrium_evolver.allocate',
#   'ecoli-equilibrium_evolver.bulk',
#   'ecoli-equilibrium_evolver.global_time',
#   'ecoli-equilibrium_evolver.listeners',
#   'ecoli-equilibrium_evolver.next_update_time',
#   'ecoli-equilibrium_evolver.process',
#   'ecoli-equilibrium_evolver.timestep',
#   'ecoli-equilibrium_requester.bulk',
#   'ecoli-equilibrium_requester.global_time',
#   'ecoli-equilibrium_requester.listeners',
#   'ecoli-equilibrium_requester.next_update_time',
#   'ecoli-equilibrium_requester.process',
#   'ecoli-equilibrium_requester.request',
#   'ecoli-equilibrium_requester.timestep',
#   'ecoli-mass-listener.bulk',
#   'ecoli-mass-listener.global_time',
#   'ecoli-mass-listener.listeners',
#   'ecoli-mass-listener.timestep',
#   'ecoli-mass-listener.unique',
#   'ecoli-metabolism.boundary',
#   'ecoli-metabolism.bulk',
#   'ecoli-metabolism.bulk_total',
#   'ecoli-metabolism.environment._path',
#   'ecoli-metabolism.environment.exchange',
#   'ecoli-metabolism.global_time',
#   'ecoli-metabolism.listeners',
#   'ecoli-metabolism.next_update_time',
#   'ecoli-metabolism.polypeptide_elongation',
#   'ecoli-metabolism.timestep',
#   'ecoli-polypeptide-elongation_evolver.active_ribosome',
#   'ecoli-polypeptide-elongation_evolver.allocate',
#   'ecoli-polypeptide-elongation_evolver.boundary',
#   'ecoli-polypeptide-elongation_evolver.bulk',
#   'ecoli-polypeptide-elongation_evolver.bulk_total',
#   'ecoli-polypeptide-elongation_evolver.environment',
#   'ecoli-polypeptide-elongation_evolver.global_time',
#   'ecoli-polypeptide-elongation_evolver.listeners',
#   'ecoli-polypeptide-elongation_evolver.next_update_time',
#   'ecoli-polypeptide-elongation_evolver.polypeptide_elongation',
#   'ecoli-polypeptide-elongation_evolver.process',
#   'ecoli-polypeptide-elongation_evolver.timestep',
#   'ecoli-polypeptide-elongation_requester.active_ribosome',
#   'ecoli-polypeptide-elongation_requester.boundary',
#   'ecoli-polypeptide-elongation_requester.bulk',
#   'ecoli-polypeptide-elongation_requester.bulk_total',
#   'ecoli-polypeptide-elongation_requester.environment',
#   'ecoli-polypeptide-elongation_requester.global_time',
#   'ecoli-polypeptide-elongation_requester.listeners',
#   'ecoli-polypeptide-elongation_requester.next_update_time',
#   'ecoli-polypeptide-elongation_requester.polypeptide_elongation',
#   'ecoli-polypeptide-elongation_requester.process',
#   'ecoli-polypeptide-elongation_requester.request',
#   'ecoli-polypeptide-elongation_requester.timestep',
#   'ecoli-polypeptide-initiation_evolver.RNA',
#   'ecoli-polypeptide-initiation_evolver.active_ribosome',
#   'ecoli-polypeptide-initiation_evolver.allocate',
#   'ecoli-polypeptide-initiation_evolver.bulk',
#   'ecoli-polypeptide-initiation_evolver.environment',
#   'ecoli-polypeptide-initiation_evolver.global_time',
#   'ecoli-polypeptide-initiation_evolver.listeners',
#   'ecoli-polypeptide-initiation_evolver.next_update_time',
#   'ecoli-polypeptide-initiation_evolver.process',
#   'ecoli-polypeptide-initiation_evolver.timestep',
#   'ecoli-polypeptide-initiation_requester.RNA',
#   'ecoli-polypeptide-initiation_requester.active_ribosome',
#   'ecoli-polypeptide-initiation_requester.bulk',
#   'ecoli-polypeptide-initiation_requester.environment',
#   'ecoli-polypeptide-initiation_requester.global_time',
#   'ecoli-polypeptide-initiation_requester.listeners',
#   'ecoli-polypeptide-initiation_requester.next_update_time',
#   'ecoli-polypeptide-initiation_requester.process',
#   'ecoli-polypeptide-initiation_requester.request',
#   'ecoli-polypeptide-initiation_requester.timestep',
#   'ecoli-protein-degradation_evolver.allocate',
#   'ecoli-protein-degradation_evolver.bulk',
#   'ecoli-protein-degradation_evolver.global_time',
#   'ecoli-protein-degradation_evolver.next_update_time',
#   'ecoli-protein-degradation_evolver.process',
#   'ecoli-protein-degradation_evolver.timestep',
#   'ecoli-protein-degradation_requester.bulk',
#   'ecoli-protein-degradation_requester.global_time',
#   'ecoli-protein-degradation_requester.next_update_time',
#   'ecoli-protein-degradation_requester.process',
#   'ecoli-protein-degradation_requester.request',
#   'ecoli-protein-degradation_requester.timestep',
#   'ecoli-rna-degradation_evolver.RNAs',
#   'ecoli-rna-degradation_evolver.active_ribosome',
#   'ecoli-rna-degradation_evolver.allocate',
#   'ecoli-rna-degradation_evolver.bulk',
#   'ecoli-rna-degradation_evolver.global_time',
#   'ecoli-rna-degradation_evolver.listeners',
#   'ecoli-rna-degradation_evolver.next_update_time',
#   'ecoli-rna-degradation_evolver.process',
#   'ecoli-rna-degradation_evolver.timestep',
#   'ecoli-rna-degradation_requester.RNAs',
#   'ecoli-rna-degradation_requester.active_ribosome',
#   'ecoli-rna-degradation_requester.bulk',
#   'ecoli-rna-degradation_requester.global_time',
#   'ecoli-rna-degradation_requester.listeners',
#   'ecoli-rna-degradation_requester.next_update_time',
#   'ecoli-rna-degradation_requester.process',
#   'ecoli-rna-degradation_requester.request',
#   'ecoli-rna-degradation_requester.timestep',
#   'ecoli-rna-maturation_evolver.allocate',
#   'ecoli-rna-maturation_evolver.bulk',
#   'ecoli-rna-maturation_evolver.bulk_total',
#   'ecoli-rna-maturation_evolver.global_time',
#   'ecoli-rna-maturation_evolver.listeners',
#   'ecoli-rna-maturation_evolver.next_update_time',
#   'ecoli-rna-maturation_evolver.process',
#   'ecoli-rna-maturation_requester.bulk',
#   'ecoli-rna-maturation_requester.bulk_total',
#   'ecoli-rna-maturation_requester.global_time',
#   'ecoli-rna-maturation_requester.listeners',
#   'ecoli-rna-maturation_requester.next_update_time',
#   'ecoli-rna-maturation_requester.process',
#   'ecoli-rna-maturation_requester.request',
#   'ecoli-tf-binding.bulk',
#   'ecoli-tf-binding.bulk_total',
#   'ecoli-tf-binding.global_time',
#   'ecoli-tf-binding.listeners',
#   'ecoli-tf-binding.next_update_time',
#   'ecoli-tf-binding.promoters',
#   'ecoli-tf-binding.timestep',
#   'ecoli-tf-unbinding.bulk',
#   'ecoli-tf-unbinding.global_time',
#   'ecoli-tf-unbinding.next_update_time',
#   'ecoli-tf-unbinding.promoters',
#   'ecoli-tf-unbinding.timestep',
#   'ecoli-transcript-elongation_evolver.RNAs',
#   'ecoli-transcript-elongation_evolver.active_RNAPs',
#   'ecoli-transcript-elongation_evolver.allocate',
#   'ecoli-transcript-elongation_evolver.bulk',
#   'ecoli-transcript-elongation_evolver.bulk_total',
#   'ecoli-transcript-elongation_evolver.environment',
#   'ecoli-transcript-elongation_evolver.global_time',
#   'ecoli-transcript-elongation_evolver.listeners',
#   'ecoli-transcript-elongation_evolver.next_update_time',
#   'ecoli-transcript-elongation_evolver.process',
#   'ecoli-transcript-elongation_evolver.timestep',
#   'ecoli-transcript-elongation_requester.RNAs',
#   'ecoli-transcript-elongation_requester.active_RNAPs',
#   'ecoli-transcript-elongation_requester.bulk',
#   'ecoli-transcript-elongation_requester.bulk_total',
#   'ecoli-transcript-elongation_requester.environment',
#   'ecoli-transcript-elongation_requester.global_time',
#   'ecoli-transcript-elongation_requester.listeners',
#   'ecoli-transcript-elongation_requester.next_update_time',
#   'ecoli-transcript-elongation_requester.process',
#   'ecoli-transcript-elongation_requester.request',
#   'ecoli-transcript-elongation_requester.timestep',
#   'ecoli-transcript-initiation_evolver.RNAs',
#   'ecoli-transcript-initiation_evolver.active_RNAPs',
#   'ecoli-transcript-initiation_evolver.allocate',
#   'ecoli-transcript-initiation_evolver.bulk',
#   'ecoli-transcript-initiation_evolver.environment',
#   'ecoli-transcript-initiation_evolver.full_chromosomes',
#   'ecoli-transcript-initiation_evolver.global_time',
#   'ecoli-transcript-initiation_evolver.listeners',
#   'ecoli-transcript-initiation_evolver.next_update_time',
#   'ecoli-transcript-initiation_evolver.process',
#   'ecoli-transcript-initiation_evolver.promoters',
#   'ecoli-transcript-initiation_evolver.timestep',
#   'ecoli-transcript-initiation_requester.RNAs',
#   'ecoli-transcript-initiation_requester.active_RNAPs',
#   'ecoli-transcript-initiation_requester.bulk',
#   'ecoli-transcript-initiation_requester.environment',
#   'ecoli-transcript-initiation_requester.full_chromosomes',
#   'ecoli-transcript-initiation_requester.global_time',
#   'ecoli-transcript-initiation_requester.listeners',
#   'ecoli-transcript-initiation_requester.next_update_time',
#   'ecoli-transcript-initiation_requester.process',
#   'ecoli-transcript-initiation_requester.promoters',
#   'ecoli-transcript-initiation_requester.request',
#   'ecoli-transcript-initiation_requester.timestep',
#   'ecoli-two-component-system_evolver.allocate',
#   'ecoli-two-component-system_evolver.bulk',
#   'ecoli-two-component-system_evolver.global_time',
#   'ecoli-two-component-system_evolver.listeners',
#   'ecoli-two-component-system_evolver.next_update_time',
#   'ecoli-two-component-system_evolver.process',
#   'ecoli-two-component-system_evolver.timestep',
#   'ecoli-two-component-system_requester.bulk',
#   'ecoli-two-component-system_requester.global_time',
#   'ecoli-two-component-system_requester.listeners',
#   'ecoli-two-component-system_requester.next_update_time',
#   'ecoli-two-component-system_requester.process',
#   'ecoli-two-component-system_requester.request',
#   'ecoli-two-component-system_requester.timestep',
#   'exchange_data.boundary',
#   'exchange_data.environment',
#   'global_clock.global_time',
#   'global_clock.next_update_time',
#   'mark_d_period.divide',
#   'mark_d_period.full_chromosome',
#   'mark_d_period.global_time',
#   'media_update.boundary',
#   'media_update.environment',
#   'monomer_counts_listener.bulk',
#   'monomer_counts_listener.global_time',
#   'monomer_counts_listener.listeners',
#   'monomer_counts_listener.timestep',
#   'monomer_counts_listener.unique',
#   'post-division-mass-listener.bulk',
#   'post-division-mass-listener.global_time',
#   'post-division-mass-listener.listeners',
#   'post-division-mass-listener.timestep',
#   'post-division-mass-listener.unique',
#   'replication_data_listener.DnaA_boxes',
#   'replication_data_listener.active_replisomes',
#   'replication_data_listener.global_time',
#   'replication_data_listener.listeners',
#   'replication_data_listener.oriCs',
#   'replication_data_listener.timestep',
#   'ribosome_data_listener.RNAs',
#   'ribosome_data_listener.active_ribosomes',
#   'ribosome_data_listener.global_time',
#   'ribosome_data_listener.listeners',
#   'ribosome_data_listener.next_update_time',
#   'ribosome_data_listener.timestep',
#   'rna_synth_prob_listener.genes',
#   'rna_synth_prob_listener.global_time',
#   'rna_synth_prob_listener.promoters',
#   'rna_synth_prob_listener.rna_synth_prob',
#   'rna_synth_prob_listener.timestep',
#   'rnap_data_listener.RNAs',
#   'rnap_data_listener.active_RNAPs',
#   'rnap_data_listener.active_ribosomes',
#   'rnap_data_listener.global_time',
#   'rnap_data_listener.listeners',
#   'rnap_data_listener.next_update_time',
#   'rnap_data_listener.timestep',
#   'unique_molecule_counts.global_time',
#   'unique_molecule_counts.listeners',
#   'unique_molecule_counts.timestep',
#   'unique_molecule_counts.unique',
#   'unique_update_1.DnaA_boxes',
#   'unique_update_1.RNAs',
#   'unique_update_1.active_RNAPs',
#   'unique_update_1.active_replisomes',
#   'unique_update_1.active_ribosome',
#   'unique_update_1.chromosomal_segments',
#   'unique_update_1.chromosome_domains',
#   'unique_update_1.full_chromosomes',
#   'unique_update_1.genes',
#   'unique_update_1.oriCs',
#   'unique_update_1.promoters',
#   'unique_update_10.DnaA_boxes',
#   'unique_update_10.RNAs',
#   'unique_update_10.active_RNAPs',
#   'unique_update_10.active_replisomes',
#   'unique_update_10.active_ribosome',
#   'unique_update_10.chromosomal_segments',
#   'unique_update_10.chromosome_domains',
#   'unique_update_10.full_chromosomes',
#   'unique_update_10.genes',
#   'unique_update_10.oriCs',
#   'unique_update_10.promoters',
#   'unique_update_11.DnaA_boxes',
#   'unique_update_11.RNAs',
#   'unique_update_11.active_RNAPs',
#   'unique_update_11.active_replisomes',
#   'unique_update_11.active_ribosome',
#   'unique_update_11.chromosomal_segments',
#   'unique_update_11.chromosome_domains',
#   'unique_update_11.full_chromosomes',
#   'unique_update_11.genes',
#   'unique_update_11.oriCs',
#   'unique_update_11.promoters',
#   'unique_update_2.DnaA_boxes',
#   'unique_update_2.RNAs',
#   'unique_update_2.active_RNAPs',
#   'unique_update_2.active_replisomes',
#   'unique_update_2.active_ribosome',
#   'unique_update_2.chromosomal_segments',
#   'unique_update_2.chromosome_domains',
#   'unique_update_2.full_chromosomes',
#   'unique_update_2.genes',
#   'unique_update_2.oriCs',
#   'unique_update_2.promoters',
#   'unique_update_3.DnaA_boxes',
#   'unique_update_3.RNAs',
#   'unique_update_3.active_RNAPs',
#   'unique_update_3.active_replisomes',
#   'unique_update_3.active_ribosome',
#   'unique_update_3.chromosomal_segments',
#   'unique_update_3.chromosome_domains',
#   'unique_update_3.full_chromosomes',
#   'unique_update_3.genes',
#   'unique_update_3.oriCs',
#   'unique_update_3.promoters',
#   'unique_update_4.DnaA_boxes',
#   'unique_update_4.RNAs',
#   'unique_update_4.active_RNAPs',
#   'unique_update_4.active_replisomes',
#   'unique_update_4.active_ribosome',
#   'unique_update_4.chromosomal_segments',
#   'unique_update_4.chromosome_domains',
#   'unique_update_4.full_chromosomes',
#   'unique_update_4.genes',
#   'unique_update_4.oriCs',
#   'unique_update_4.promoters',
#   'unique_update_5.DnaA_boxes',
#   'unique_update_5.RNAs',
#   'unique_update_5.active_RNAPs',
#   'unique_update_5.active_replisomes',
#   'unique_update_5.active_ribosome',
#   'unique_update_5.chromosomal_segments',
#   'unique_update_5.chromosome_domains',
#   'unique_update_5.full_chromosomes',
#   'unique_update_5.genes',
#   'unique_update_5.oriCs',
#   'unique_update_5.promoters',
#   'unique_update_6.DnaA_boxes',
#   'unique_update_6.RNAs',
#   'unique_update_6.active_RNAPs',
#   'unique_update_6.active_replisomes',
#   'unique_update_6.active_ribosome',
#   'unique_update_6.chromosomal_segments',
#   'unique_update_6.chromosome_domains',
#   'unique_update_6.full_chromosomes',
#   'unique_update_6.genes',
#   'unique_update_6.oriCs',
#   'unique_update_6.promoters',
#   'unique_update_7.DnaA_boxes',
#   'unique_update_7.RNAs',
#   'unique_update_7.active_RNAPs',
#   'unique_update_7.active_replisomes',
#   'unique_update_7.active_ribosome',
#   'unique_update_7.chromosomal_segments',
#   'unique_update_7.chromosome_domains',
#   'unique_update_7.full_chromosomes',
#   'unique_update_7.genes',
#   'unique_update_7.oriCs',
#   'unique_update_7.promoters',
#   'unique_update_8.DnaA_boxes',
#   'unique_update_8.RNAs',
#   'unique_update_8.active_RNAPs',
#   'unique_update_8.active_replisomes',
#   'unique_update_8.active_ribosome',
#   'unique_update_8.chromosomal_segments',
#   'unique_update_8.chromosome_domains',
#   'unique_update_8.full_chromosomes',
#   'unique_update_8.genes',
#   'unique_update_8.oriCs',
#   'unique_update_8.promoters',
#   'unique_update_9.DnaA_boxes',
#   'unique_update_9.RNAs',
#   'unique_update_9.active_RNAPs',
#   'unique_update_9.active_replisomes',
#   'unique_update_9.active_ribosome',
#   'unique_update_9.chromosomal_segments',
#   'unique_update_9.chromosome_domains',
#   'unique_update_9.full_chromosomes',
#   'unique_update_9.genes',
#   'unique_update_9.oriCs',
#   'unique_update_9.promoters'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6 from rustworkx.visualization import mpl_draw as draw_graph
#       7 import numpy as np
# ----> 9 n = len(paths)
#      11 G = rx.PyGraph()
#      12 graph.add_nodes_from(np.arange(0, n, 1))
#
# TypeError: object of type 'NoneType' has no len()
